# %%
# n gram

# n-grams help us to analyze the relationship between neighboring words
# n-gram =a sequence of n tokens
# n=1 unigrams
# n=2 =bigrams
#n=3 trigrams

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
tokens =['the','rise','of','artiificial','intelligence','and','machine','learning   is','transforming','the','world of','technology and','business  and','creating','new','opportunities','and','challenges for','organizations and','individuals   alike.','the','integration of','ai and','ml is','driving innovation and','reshaping','industries across the globe.  from','healthcare to','finance,','education to','transportation,','ai and','ml are','revolutionizing the way we live and work.  as','we continue to','embrace the potential of ai and ml, it is crucial to','navigate the ethical considerations and ensure that these technologies are used responsibly for the benefit of society as a whole. ']
print(tokens)
# Out:
# ['the', 'rise', 'of', 'artiificial', 'intelligence', 'and', 'machine', 'learning   is', 'transforming', 'the', 'world of', 'technology and', 'business  and', 'creating', 'new', 'opportunities', 'and', 'challenges for', 'organizations and', 'individuals   alike.', 'the', 'integration of', 'ai and', 'ml is', 'driving innovation and', 'reshaping', 'industries across the globe.  from', 'healthcare to', 'finance,', 'education to', 'transportation,', 'ai and', 'ml are', 'revolutionizing the way we live and work.  as', 'we continue to', 'embrace the potential of ai and ml, it is crucial to', 'navigate the ethical considerations and ensure that these technologies are used responsibly for the benefit of society as a whole. ']

# %%
unigrams =(pd.Series(nltk.ngrams(tokens,1)).value_counts( ))
print(unigrams[:10])
# Out:
# (the,)              3
# (and,)              2
# (ai and,)           2
# (rise,)             1
# (of,)               1
# (artiificial,)      1
# (intelligence,)     1
# (machine,)          1
# (learning   is,)    1
# (transforming,)     1
# Name: count, dtype: int64

# %%
unigrams[:10].sort_values().plot.barh(color='lightsalmon',width=9,figsize=(12,5))
plt.title('ten most requently occuring unigrams')
# Out:
# Text(0.5, 1.0, 'ten most requently occuring unigrams')

# %%
bigrams =(pd.Series(nltk.ngrams(tokens,2)).value_counts( ))
print(bigrams[:10])
# Out:
# (the, rise)                      1
# (rise, of)                       1
# (of, artiificial)                1
# (artiificial, intelligence)      1
# (intelligence, and)              1
# (and, machine)                   1
# (machine, learning   is)         1
# (learning   is, transforming)    1
# (transforming, the)              1
# (the, world of)                  1
# Name: count, dtype: int64

# %%
trigrams =(pd.Series(nltk.ngrams(tokens,3)).value_counts( ))
print(trigrams[:10])
# Out:
# (the, rise, of)                           1
# (rise, of, artiificial)                   1
# (of, artiificial, intelligence)           1
# (artiificial, intelligence, and)          1
# (intelligence, and, machine)              1
# (and, machine, learning   is)             1
# (machine, learning   is, transforming)    1
# (learning   is, transforming, the)        1
# (transforming, the, world of)             1
# (the, world of, technology and)           1
# Name: count, dtype: int64
